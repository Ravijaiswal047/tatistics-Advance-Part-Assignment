# %% [markdown]
# <a href="https://colab.research.google.com/github/Ravijaiswal047/tatistics-Advance-Part-Assignment/blob/main/Statistics_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1.  What is hypothesis testing in statistics?
# sol. Hypothesis testing is a statistical method used to determine whether there is
# enough evidence to reject a null hypothesis(Ho)in favor of an alternative hypothesis (Ho)
# >> Null Hypothesis (Ho)Assumes no effect or difference.
# >> Alternative Hypothesis (Ho): Suggests an effect or difference exists.
# >> Significance Level (alpha) : The probability of rejecting (Ho) when it's true (e.g., 0.05)
# >> Test Statistic - A value (e.g., Z-score, t-score) calculated from sample data.
# >> P-value - if p-value < alpha , reject Ho; otherwise , fail to reject Ho

# 2. What is the null hypothesis, and how does it differ from the alternative hypothesis?
# sol2. A null hypothesis is a statement in statistical testing that assumes
# there is "no effect" or "no difference" between variables, essentially claiming that
# any observed results are due to chance, while the alternative hypothesis is the opposing
# statement that proposes a significant effect or relationship exists between variables,
#  which is what the researcher is typically trying to prove by rejecting the null hypothesis.

# 3. What is the significance level in hypothesis testing, and why is it important?
# sol. The significance level is the probability of rejecting the null hypothesis
# when it is actually true (Type I error). It determines statistical significance, with common values like 0.05 (5%) or 0.01
# (1%). If p-value < alpha we reject Ho. It helps control errors and ensures reliable conclusions.

# 4.What does a P-value represent in hypothesis testing?
# sol. The p-value represents the probability of obtaining a test result at least as
# extreme as the observed data, assuming the null hypothesis Ho is true.

# 5. How do you interpret the P-value in hypothesis testing?
# sol. The p-value only tells you how likely the data you have observed is to have occurred under the null hypothesis.
#  If the p-value is below your threshold of significance (typically p < 0.05), then you can reject the null hypothesis,
#  but this does not necessarily mean that your alternative hypothesis is true.

# 6. What are Type 1 and Type 2 errors in hypothesis testing
# sol. Type 1 and type 2 errors are mistakes that can occur when testing a hypothesis.
# They are also known as alpha and beta errors.

# 7.What is the difference between a one-tailed and a two-tailed test in hypothesis testing?
# sol. The main difference between one-tailed and two-tailed tests is that one-tailed tests will only have one critical
# region whereas two-tailed tests will have two critical regions. If we require a 100(1-alpha) 100 (1-alpha) % confidence interval
# we have to make some adjustments when using a two-tailed test.

# 8. What is the Z-test, and when is it used in hypothesis testing?
# sol.A z-test is a statistical test used to determine whether two population means are
# different when the variances are known and the sample size is large. It can also
# be used to compare one mean to a hypothesized value. The data must approximately fit a normal distribution,
# otherwise the test doesn't work.

# 9. How do you calculate the Z-score, and what does it represent in hypothesis testing?
# sol A Z-score is calculated by subtracting the population mean from a data point and then
# dividing the result by the population standard deviation, using the formula: z = (x - μ) / σ;
# it represents how many standard deviations a data point is away from the mean in a normal distribution, which is
# crucial in hypothesis testing to determine if a sample result is statistically significant enough to reject the null hypothesis.

# 10.  What is the T-distribution, and when should it be used instead of the normal distribution?
# sol. You must use the t-distribution table when working problems when the population standard deviation (σ)
# is not known and the sample size is small (n<30). General Correct Rule:
# If σ is not known, then using t-distribution is correct. If σ is known, then using the normal distribution is correct.

# 11. What is the difference between a Z-test and a T-test
# sol. Generally, z-tests are used when we have large sample sizes (n > 30),
# whereas t-tests are most helpful with a smaller sample size (n < 30).
# Both methods assume a normal distribution of the data, but the z-tests are most useful when the standard deviation is known.

# 12.  What is the T-test, and how is it used in hypothesis testing?
# sol. A t-test is an inferential statistic used to determine
# if there is a significant difference between the means of two groups and how they are related. T-tests are used
# when the data sets follow a normal distribution and have unknown variances, like the data set recorded from flipping a coin 100 times.

# 13. @ What is the relationship between Z-test and T-test in hypothesis testing
# sol. Generally, z-tests are used when we have large sample sizes (n > 30),
# whereas t-tests are most helpful with a smaller sample size (n < 30).
# Both methods assume a normal distribution of the data, but the z-tests are most useful when the standard deviation is known.

# 14. What is a confidence interval, and how is it used to interpret statistical results
# sol. A confidence interval shows the probability that a parameter will fall between
#  a pair of values around the mean. Confidence intervals show the degree of uncertainty or certainty in a sampling method.
# They are constructed using confidence levels of 95% or 99%

# 15. What is the margin of error, and how does it affect the confidence interval
# sol. The margin of error depends on confidence level, standard deviation, and sample size.
# For a 95% confidence level, there's a 95% probability the true value is within the interval.
# The formula, when population standard deviation is known, is: margin of error = Z * (s/√n) Where: - Z is the Z-score.

# 16. How is Bayes' Theorem used in statistics, and what is its significance
# sol. Bayes' Theorem thus gives the probability of an event based on new information
# that is or may be related to that event. The formula also can be used to determine
# how the probability of an event occurring may be affected by hypothetical new information,
# supposing the new information will turn out to be true.

# 17. What is the Chi-square distribution, and when is it used?
# sol. A Chi-square distribution is a continuous probability distribution used in statistics
# primarily for hypothesis testing, particularly when analyzing categorical data,
# to compare observed frequencies with expected frequencies, and to determine
# if there is a significant relationship between two categorical variables (like a "test of independence") or
# how well observed data fits a theoretical distribution ("goodness of fit test")

# 18. What is the Chi-square goodness of fit test, and how is it applied
# sol. The chi-square goodness of fit test is a hypothesis test.
#  It allows you to draw conclusions about the distribution of a population based on a sample.
#  Using the chi-square goodness of fit test,
#  you can test whether the goodness of fit is “good enough” to conclude that the population follows the distribution.

# 19.  What is the F-distribution, and when is it used in hypothesis testing
# sol. The F-distribution is useful in hypothesis testing. Hypothesis testing is
# used by scientists to statistically compare data from two or more populations.
# The F-distribution is needed to determine whether the F-value for a study indicates
# any statistically significant differences between two populations

# 20. What is an ANOVA test, and what are its assumptions
# sol. ANOVA, which stands for Analysis of Variance, is a statistical method used to
# analyze data from studies with multiple groups. ANOVA is widely used in biomedical
# research to compare means across multiple groups in order to determine whether the differences observed are statistically significant

# 21. What are the different types of ANOVA tests
# sol. There are two types of ANOVA that are commonly used, the one-way ANOVA and the two-way ANOVA.
# This article will explore this important statistical test and the difference between these two types of ANOVA.

# 22. What is the F-test, and how does it relate to hypothesis testing
# sol. An F-test is any statistical test used to compare the variances of two samples or
# the ratio of variances between multiple samples. The test statistic, random variable F,
# is used to determine if the tested data has an F-distribution under the true null hypothesis,
# and true customary assumptions about the error term (ε).
